# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dicionário de faturamento
dict_faturamento = {
    'data_ref': [
        '2023-01-01', 
        '2020-02-01', 
        '2021-03-01', 
        '2022-04-01', 
        '2023-05-01',
        '2023-06-01', 
        '2020-07-01', 
        '2021-08-01', 
        '2022-09-01', 
        '2023-10-01',
        '2022-11-01', 
        '2023-12-01',
        ],
    'valor': [
        400000, 
        890000, 
        760000, 
        430000, 
        920000,
        340000, 
        800000, 
        500000, 
        200000, 
        900000,
        570000, 
        995000,
        ]
}

df_faturamento = pd.DataFrame.from_dict(dict_faturamento)
df_faturamento
# Out:
#       data_ref   valor
# 0   2023-01-01  400000
# 1   2020-02-01  890000
# 2   2021-03-01  760000
# 3   2022-04-01  430000
# 4   2023-05-01  920000
# 5   2023-06-01  340000
# 6   2020-07-01  800000
# 7   2021-08-01  500000
# 8   2022-09-01  200000
# 9   2023-10-01  900000
# 10  2022-11-01  570000
# 11  2023-12-01  995000

# %%
# Media das vendas
df_faturamento["valor"].mean()
# Out:
# np.float64(642083.3333333334)

# %%
#formatando a data para tipo data
df_faturamento['data_ref'] = pd.to_datetime(df_faturamento['data_ref'])
# grafico de barras vertical
df_faturamento.plot.bar(x='data_ref',y='valor').set_xticklabels(df_faturamento['data_ref'].dt.strftime('%Y-%m-%d'))
# Out:
# [Text(0, 0, '2023-01-01'),
#  Text(1, 0, '2020-02-01'),
#  Text(2, 0, '2021-03-01'),
#  Text(3, 0, '2022-04-01'),
#  Text(4, 0, '2023-05-01'),
#  Text(5, 0, '2023-06-01'),
#  Text(6, 0, '2020-07-01'),
#  Text(7, 0, '2021-08-01'),
#  Text(8, 0, '2022-09-01'),
#  Text(9, 0, '2023-10-01'),
#  Text(10, 0, '2022-11-01'),
#  Text(11, 0, '2023-12-01')]

# %%
# Grafico de linhas mes de referencia e valor (Ordenadado por data)
df_faturamento.sort_values('data_ref').plot.line(x='data_ref',y='valor')
# Out:
# <Axes: xlabel='data_ref'>
